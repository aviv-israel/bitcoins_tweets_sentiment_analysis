# %% [markdown]
# ## Plotting the price history for bitcoin:

# %%
import yfinance as yf

# %%
stock = yf.Ticker('BTC-USD')

# get bitcoin info
print(stock.info)

# get historical market data
hist = stock.history(period="100D")
# Out:
# {'companyOfficers': [], 'name': 'Bitcoin', 'startDate': 1367107200, 'description': 'Bitcoin (BTC) is a cryptocurrency . Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,107,981. The last known price of Bitcoin is 23,742.52712784 USD and is down -0.38 over the last 24 hours. It is currently trading on 9648 active market(s) with $28,249,859,104.32 traded over the last 24 hours. More information can be found at https://bitcoin.org/.', 'maxAge': 1, 'exchange': 'CCC', 'shortName': 'Bitcoin USD', 'exchangeTimezoneName': 'UTC', 'exchangeTimezoneShortName': 'UTC', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '0', 'quoteType': 'CRYPTOCURRENCY', 'symbol': 'BTC-USD', 'messageBoardId': 'finmb_BTC_CCC', 'market': 'ccc_market', 'previousClose': 23637.914, 'regularMarketOpen': 23637.914, 'twoHundredDayAverage': 34269.594, 'trailingAnnualDividendYield': None, 'payoutRatio': None, 'volume24Hr': 27283079168, 'regularMarketDayHigh': 23845.682, 'navPrice': None, 'averageDailyVolume10Day': 32763023784, 'totalAssets': None, 'regularMarketPreviousClose': 23637.914, 'fiftyDayAverage': 21593.426, 'trailingAnnualDividendRate': None, 'open': 23637.914, 'toCurrency': 'USD=X', 'averageVolume10days': 32763023784, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': None, 'beta': None, 'circulatingSupply': 19108218, 'regularMarketDayLow': 23631.305, 'priceHint': 2, 'currency': 'USD', 'regularMarketVolume': 27283079168, 'lastMarket': 'CoinMarketCap', 'maxSupply': None, 'openInterest': None, 'marketCap': 454332416000, 'volumeAllCurrencies': 27283079168, 'strikePrice': None, 'averageVolume': 32283434231, 'priceToSalesTrailing12Months': None, 'dayLow': 23631.305, 'ask': None, 'ytdReturn': None, 'askSize': None, 'volume': 27283079168, 'fiftyTwoWeekHigh': 68789.625, 'forwardPE': None, 'fromCurrency': 'BTC', 'fiveYearAvgDividendYield': None, 'fiftyTwoWeekLow': 17708.623, 'bid': None, 'tradeable': False, 'dividendYield': None, 'bidSize': None, 'dayHigh': 23845.682, 'coinMarketCapLink': 'https://coinmarketcap.com/currencies/bitcoin', 'regularMarketPrice': 23776.807, 'preMarketPrice': None, 'logo_url': ''}

# %%
# Plot everything by leveraging the very powerful matplotlib package
hist['Close'].plot(figsize=(16, 9))
# Out:
# <AxesSubplot:xlabel='Date'>
